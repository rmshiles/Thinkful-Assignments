# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
#import matplotlib.animation as animation 
#from mpl_toolkits.basemap import Basemap

import seaborn as sns
#import warnings
#warnings.filterwarnings('ignore')

# %%
Deep_Solar_df = pd.read_csv('deepsolar_tract.csv',  encoding='latin1')

# %% [markdown]
# Choose one variable and plot that variable four different ways.

# %%
#Create 4 subplots 
plt.figure(figsize=(24,12))
#subplot 1
plt.subplot(2, 2, 1)

# Setting the overall aesthetic.
sns.set(style="whitegrid")
sns.pointplot(x="daily_solar_radiation", y=None, hue=None, data=Deep_Solar_df,
                   height=6, kind="strip", palette="pastel",ci=95,dodge=True,join=False)
plt.title('Pointplot: Meal Tips by Time and Gender')


#subplot 2
plt.subplot(2, 2, 2)

# Comparing groups using boxplots.
ax = sns.boxplot(x=None,y=None,hue=None,data=Deep_Solar_df['daily_solar_radiation'])  
plt.title('Plot 3: Meal Tips by Gender and Time')
sns.despine(offset=10, trim=True)
ax.set(xlabel='', ylabel='Tips')




#subplot 3
plt.subplot(2, 2, 3)

sns.set(style='darkgrid')
sns.violinplot(data=Deep_Solar_df['daily_solar_radiation'], palette='pink', inner="points")


#subplot 4
plt.subplot(2, 2, 4)
plt.hist(Deep_Solar_county['daily_solar_radiation'],bins=100, color='green', alpha=0.5 )

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b313267e7540> in <module>
#      32 #subplot 4
#      33 plt.subplot(2, 2, 4)
# ---> 34 plt.hist(Deep_Solar_county['daily_solar_radiation'],bins=100, color='green', alpha=0.5 )
#      35
#      36 plt.show()
#
# NameError: name 'Deep_Solar_county' is not defined

# %% [markdown]
# Choose two continuous variables, and plot them three different ways.

# %%
g = sns.lmplot(y='daily_solar_radiation', 
               x='lat',
               data=Deep_Solar_df, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})


plt.show()

# %%
sns.set(style="white")

# Generate a random correlated bivariate dataset


#x1, x2 = rs.multivariate_normal(mean, cov, 500).T
x1 = Deep_Solar_df['daily_solar_radiation']
x2 = Deep_Solar_df['lat']

# Show the joint distribution using kernel density estimation
k = sns.jointplot(x1, x2, kind="kde", height=7, space=0)

plt.show()

# %%
ax = sns.lineplot(x='daily_solar_radiation', y='lat', data=Deep_Solar_df)

# %%
 g = sns.jointplot(x='daily_solar_radiation', y='lat', data=Deep_Solar_df)

# %% [markdown]
# Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
power_plants = pd.read_csv('global_power_plant_database.csv')
power_plants.describe()
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  \
# count  29910.000000  29910.000000  29910.000000        16303.000000
# mean     186.294810     32.497558    -12.458680         1995.486227
# std      525.703572     23.654472     76.978265           23.525537
# min        1.000000    -77.847000   -179.977700         1896.000000
# 25%        4.774430     28.863475    -79.211275         1986.000000
# 50%       18.900000     40.071250     -3.746700         2005.000000
# 75%      100.000000     47.134575     24.931050         2012.063866
# max    22500.000000     71.292000    179.388700         2018.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count           13743.000000          6996.000000          7440.000000
# mean             2016.860001           689.625437           664.840134
# std                 1.195205          2330.869715          2258.351290
# min              2000.000000          -947.600000          -989.619000
# 25%              2017.000000             2.167000             2.157000
# 50%              2017.000000            27.033000            23.005000
# 75%              2017.000000           250.600500           224.955250
# max              2018.000000         50834.000000         32320.917000
#
#        generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# count          8144.000000          8971.000000          9213.000000
# mean            664.270784           583.622877           579.524723
# std            2304.225386          2097.603620          2063.070235
# min            -864.428000          -768.620000          -934.944000
# 25%               2.350250             2.380500             3.202000
# 50%              22.094000            17.862000            20.462000
# 75%             238.437917           187.084835           192.567000
# max           59546.865000         32377.477000         35116.000000
#
#        estimated_generation_gwh
# count              21791.000000
# mean                 847.036474
# std                 4067.434967
# min                    0.000000
# 25%                   10.082961
# 50%                   53.417041
# 75%                  339.874490
# max               450562.692350

# %%
sns.set(style="whitegrid")

primary_fuel  = ["Hydro", "Gas","Nuclear", "Coal","Oil","Solar","Wind","Biomass"]

sns.boxenplot(x="primary_fuel", y="capacity_mw",
              color='b', order=primary_fuel,
              scale="linear", data=power_plants)

# %%
plt.figure(figsize=(24,12))
# Show each distribution with both violins and points
primary_fuel  = ["Hydro", "Gas","Nuclear", "Coal","Oil","Solar","Wind","Biomass"]

sns.violinplot(x='primary_fuel', y='capacity_mw',hue = 'primary_fuel', data=power_plants, order = primary_fuel, scale='width', width = 10)

# %%
plt.figure(figsize=(24,12))
# Show each distribution with both violins and points
primary_fuel  = ["Hydro", "Gas","Nuclear", "Coal","Oil","Solar","Wind","Biomass"]
 
    
g = sns.pointplot(x="primary_fuel", y="capacity_mw", hue="primary_fuel", data=power_plants,
                   height=6, kind="strip", palette="pastel",ci=95,dodge=True,join=False)

# %%
#sns.boxplot(x="distance", y="method", data=planets,
 #           whis="range", palette="vlag")


plt.figure(figsize=(24,12))

sns.boxplot(x="primary_fuel", y="capacity_mw", hue="primary_fuel", data=power_plants,
                     width = 10,palette="rainbow",dodge=True)

# %%
plt.figure(figsize=(48,34))

g = sns.catplot(x='primary_fuel', y='capacity_mw', hue="primary_fuel",
                data=power_plants,
                height=5, aspect=5)

# %%
g = sns.catplot(x="capacity_mw", y="primary_fuel",
                hue="primary_fuel",# row="primary_fuel",
                data=power_plants,
                orient="h", height=20, aspect=1, palette="Set3",
                kind="violin",ci=95 , dodge=True, cut=0, bw=1)

# %%
#sns.set(style="whitegrid")

solar = power_plants.query("primary_fuel == 'Solar'",)

ax = sns.swarmplot(x='primary_fuel', y="capacity_mw", data=solar)

# %%
plt.figure(figsize=(48,34))

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})


# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(power_plants, row='primary_fuel', hue='primary_fuel', aspect=5, height=1, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "capacity_mw", clip_on=False, color="w", lw=8, bw=10 )#, clip_on=False, shade=True, alpha=1, lw=2, bw=1)
g.map(sns.kdeplot, "capacity_mw", clip_on=False, color="b", lw=1, bw=10)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "capacity_mw")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)

# %% [markdown]
# Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.

# %% [markdown]
# I think the Boxen Plot and the violin plots where my favorite for graphing this data set they seem to show the most data and are fun to look at

# %% [markdown]
# Find a dataset with at least four continuous variables and one categorical variable.
#
# Create one master plot that gives insight into the variables and their interrelationships, including:
# - Probability distributions
# - Bivariate relationships
# - Whether the distributions or the relationships vary across groups
# - Accompany your plot with a written description of what you see.

# %%
#sns.set()
plt.figure(figsize=(24,12))
mpg = sns.load_dataset("mpg")
Japan = mpg.query("origin == 'japan'")
USA = mpg.query("origin == 'usa'")
Europe = mpg.query("origin == 'europe'")

# Load the iris dataset

plt.subplot(2,2,1)
#sns.set()

# Plot sepal with as a function of sepal_length across days hue="origin",height=5,truncate=True,

g = sns.regplot(x="weight", y="mpg", data=Japan, color = 'orange',scatter=True,fit_reg=True,lowess=True, ci=100)
g = sns.regplot(x="weight", y="mpg", data=USA,color = 'b',scatter=True,fit_reg=True,lowess=True, ci=0.5)
g = sns.regplot(x="weight", y="mpg", data=Europe,color = 'g',scatter=True,fit_reg=True,lowess=True, ci=0.5)


# Use more informative axis labels than are provided by default
#g.set_axis_labels("Sepal length (mm)", "Sepal width (mm)")
plt.title('Pointplot: weight and miles per gallon')

plt.subplot(2,2,2)
sns.set(style='darkgrid')

# Plot sepal with as a function of sepal_length across days
g = sns.violinplot(x="cylinders", y="mpg", hue="origin",
               truncate=True, height=5, data=mpg)

plt.subplot(2,2,3)
#sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lineplot(x="model_year", y="mpg", data=Japan, color = 'orange')
g = sns.lineplot(x="model_year", y="mpg", data=USA,color = 'b')
g = sns.lineplot(x="model_year", y="mpg", data=Europe,color = 'g')
 
plt.subplot(2,2,4)
sns.set(style='darkgrid')

# Plot sepal with as a function of sepal_length across days
g = sns.regplot(x="horsepower", y="mpg", data=Japan, color = 'orange',scatter=True,fit_reg=True,lowess=True, ci=100)
g = sns.regplot(x="horsepower", y="mpg", data=USA,color = 'b',scatter=True,fit_reg=True,lowess=True, ci=0.5)
g = sns.regplot(x="horsepower", y="mpg", data=Europe,color = 'g',scatter=True,fit_reg=True,lowess=True, ci=0.5)
 
plt.show()
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
